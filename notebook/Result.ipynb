# %% [markdown]
# # Displaying result

# %%
import sys
sys.executable
# Out:
# 'D:\\Programming\\anaconda3\\envs\\ml\\python.exe'

# %% [markdown]
# ## Load PCSER software

# %%
import pcser as pcs
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# #### we now display R square values (R2) and Mean squared error (MSE) between predicted and real values using the output from the model building processes.

# %% [markdown]
# ### display R squares using the minimum and maximum normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_annot_extended_minmax_spl54.txt',
    criterion='r2',
    met='minmax',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'

# %% [markdown]
# ### display MSE using the minimum and maximum normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_annot_extended_minmax_spl54.txt',
    criterion='mse',
    met='minmax',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'

# %% [markdown]
# ### display R squares using the standardisation normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_annot_extended_minmax_spl54.txt',
    criterion='r2',
    met='std',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'

# %% [markdown]
# ### display MSE using the standardisation normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_annot_extended_minmax_spl54.txt',
    criterion='mse',
    met='std',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'

# %% [markdown]
# ### display R squares using the maximum absolute normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/r2_kfold_annot_extended_minmax_spl54.txt',
    criterion='r2',
    met='maxabs',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'

# %% [markdown]
# ### display MSE using the maximum absolute normalisation method

# %%
pcs.load.plot_res(
    compo_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_compo_extended_minmax_spl54.txt',
    annot_fpn='D:/Document/Programming/Python/pcser/pcser/data/mse_kfold_annot_extended_minmax_spl54.txt',
    criterion='mse',
    met='maxabs',
)
# Out:
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# The palette list has more values (12) than needed (5), which may not be intended.
# 'Finished'
